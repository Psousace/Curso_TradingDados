# %% [markdown]
# <a href="https://colab.research.google.com/github/Psousace/Curso_TradingDados/blob/main/Fontes_de_Dados_Fundamentalistas_Alpha_Vantage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
chave_api = 'HAJNWMV235NBP9II'

# %%
# !pip  install alpha_vantage

# %%
import pandas as pd
from alpha_vantage.fundamentaldata import FundamentalData

# %%
api_key = chave_api

# %%
fd = FundamentalData(key = api_key)

# %%
ticker = "AAPL"

# %%
financials = fd.get_income_statement_annual(symbol = ticker)

# %%
type(financials)
# Out:
# tuple

# %%
financials[0]
# Out:
#   fiscalDateEnding reportedCurrency   grossProfit  totalRevenue costOfRevenue  \
# 0       2022-09-30              USD  170782000000  391397000000  248640000000
# 1       2021-09-30              USD  152836000000  363172000000  234954000000
# 2       2020-09-30              USD  104956000000  271642000000  189475000000
# 3       2019-09-30              USD   98392000000  256598000000  180027000000
# 4       2018-09-30              USD  101839000000  265595000000  163756000000
#
#   costofGoodsAndServicesSold operatingIncome sellingGeneralAndAdministrative  \
# 0               223546000000    119437000000                     25094000000
# 1               212981000000    108949000000                     21973000000
# 2               169559000000     66288000000                     19916000000
# 3               161782000000     63930000000                     18245000000
# 4               163756000000     70898000000                     16705000000
#
# ...

# %%
balance = fd.get_balance_sheet_annual(symbol = ticker)

# %%
balance[0]
# Out:
#   fiscalDateEnding reportedCurrency   totalAssets totalCurrentAssets  \
# 0       2022-09-30              USD  352755000000       135405000000
# 1       2021-09-30              USD  351002000000       134836000000
# 2       2020-09-30              USD  323888000000       143713000000
# 3       2019-09-30              USD  338516000000       162819000000
# 4       2018-09-30              USD  365725000000       131339000000
#
#   cashAndCashEquivalentsAtCarryingValue cashAndShortTermInvestments  \
# 0                           23646000000                 48304000000
# 1                           34940000000                 62639000000
# 2                           38016000000                 90943000000
# 3                           48844000000                100557000000
# 4                           25913000000                 25913000000
#
#     inventory currentNetReceivables totalNonCurrentAssets  \
# 0  4946000000           60932000000          217350000000
# ...

# %%
cashflow = fd.get_cash_flow_annual(symbol = ticker)

# %%
cashflow[0]
# Out:
#   fiscalDateEnding reportedCurrency operatingCashflow  \
# 0       2022-09-30              USD      122151000000
# 1       2021-09-30              USD      104038000000
# 2       2020-09-30              USD       80674000000
# 3       2019-09-30              USD       69391000000
# 4       2018-09-30              USD       77434000000
#
#   paymentsForOperatingActivities proceedsFromOperatingActivities  \
# 0                     4665000000                            None
# 1                     4087000000                            None
# 2                     4502000000                            None
# 3                     3423000000                            None
# 4                     3022000000                            None
#
#   changeInOperatingLiabilities changeInOperatingAssets  \
# 0                  15558000000             14358000000
# 1                  19801000000             24712000000
# 2                   6935000000              1245000000
# ...

# %%
ticker = "PETR4.SAO"

# %%
financials = fd.get_income_statement_annual(symbol = ticker)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-6cf520714bd8> in <cell line: 1>()
# ----> 1 financials = fd.get_income_statement_annual(symbol = ticker)
#
# /usr/local/lib/python3.10/dist-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     216         @wraps(func)
#     217         def _format_wrapper(self, *args, **kwargs):
# --> 218             call_response, data_key, meta_data_key = func(
#     219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#
# /usr/local/lib/python3.10/dist-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}{}'.format(url, apikey_parameter)
# --> 160             return self._handle_api_call(url), data_key, meta_data_key
# ...
