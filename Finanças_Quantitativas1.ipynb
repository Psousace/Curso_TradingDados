# %% [markdown]
# <a href="https://colab.research.google.com/github/Psousace/Curso_TradingDados/blob/main/Finan%C3%A7as_Quantitativas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Introdução a Finanças Quantitativas

# %% [markdown]
# Pontos importantes:
#
# 1. O que são finanças quantitativas?
# 2. Porque utilizamos finanças quantitativas?
# 3. Quais são as vantagens de se utilizar finanças quantitativas no dia a dia?
# 4. O que precisamos saber?
# 5. Exemplos de utilização de Python no mercado financeiro

# %% [markdown]
# # 2. Finanças Quantitativas com Python

# %% [markdown]
# Agora que já sabemos o que são finanças quantitativas, vamos começar a mostrar como podemos utilizar o Python para a implementação de técnicas de finanças quantitativas
#
# Para isso, vamos ter que relembrar de um conceito fundamental que aprendemos lá no curso de Data Science com Python
#
# E esse conceito é o das bibliotecas.
#
# Para a implementação de finanças quantitativas no Python, vamos precisar <b>muito</b> da ajuda de algumas bibliotecas. Essas bibliotecas vão ser utilizadas para obter dados de mercado financeiro, para processar, tratar e manipular esses dados, criar modelos de otimização, etc.
#
# Algumas dessas bibliotecas que vamos usar aqui:
#
# 1. pandas
# 2. numpy
# 3. seaborn
# 4. matplotlib
# 5. plotly
# 6. yfinance
# 7. pandasdatareader
# 8. MetaTrader5
# 9. Backtrader
# 10. ta
#
# Dentre outras

# %% [markdown]
# # 3. Particularidades dos dados de mercado financeiro

# %% [markdown]
# ## 3.1. Definições

# %% [markdown]
# Antes de começarmos a colocar a mão na massa de fato nos dados de mercado financeiro, é importante destacar algumas particularidades desses dados.
#
# O primeiro aspecto é a dificuldade de obtenção. Dados de mercado financeiro são difíceis de obter, por várias razões
#
# O segundo é com relação a qualidade
#
# O terceiro é uma limitação técnica, do volume que conseguimos obter
#
# O quarto é um aspecto do formato, que normalmente segue o modelo OHLC, que é Open, High, Low e Close
#
# Para ilustrar o formato OHLC, vamos fazer aqui um pequeno exercício com a biblioteca pandas para realizar o upload de uma tabela num arquivo .csv
#
# Esse arquivo contém justamente uma amostra de uma tabela de WEGE3

# %% [markdown]
# ## 3.2. Primeiros passos com dados de mercado financeiro

# %% [markdown]
# 1. Utilize o arquivo passado para você e o salve no seu PC, no mesmo endereço onde salvou este código
# 2. Uma vez que isso for concluido, você vai abrir este arquivo aqui no Python usando justamente a biblioteca pandas
# 3. A biblioteca pandas possui funções para abrir diversos tipos de arquivos, como .xlsx, .csv. .txt, sendo que aqui vamos focar no .csv
# 4. A função para abrir arquivos ".csv" é read_csv
# 5. Antes disso, precisamos abrir a biblioteca pandas

# %%
import pandas as pd

# %%
pd.read_csv('WEGE3.SA.csv')
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2017-07-24   7.392307   7.473076   7.261538   7.426923   7.051007
# 1    2017-07-25   7.476923   7.476923   7.307692   7.369230   6.996235
# 2    2017-07-26   7.323076   7.442307   7.276923   7.326923   6.956069
# 3    2017-07-27   7.388461   7.419230   7.223076   7.269230   6.901296
# 4    2017-07-28   7.261538   7.296153   7.165384   7.200000   6.835570
# ..          ...        ...        ...        ...        ...        ...
# 988  2021-07-15  35.000000  35.590000  34.900002  34.919998  34.919998
# 989  2021-07-16  35.040001  35.259998  34.209999  34.290001  34.290001
# 990  2021-07-19  34.000000  34.369999  33.599998  34.180000  34.180000
# 991  2021-07-20  34.049999  34.830002  33.869999  34.549999  34.549999
# 992  2021-07-21  34.750000  34.970001  34.099998  34.450001  34.450001
#
#         Volume
# 0    2638220.0
# 1    2505880.0
# 2    2112240.0
# 3    1910480.0
# 4    2866760.0
# ..         ...
# ...

# %%
arquivo = pd.read_csv('WEGE3.SA.csv')

# %%
arquivo.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2017-07-24  7.392307  7.473076  7.261538  7.426923   7.051007  2638220.0
# 1  2017-07-25  7.476923  7.476923  7.307692  7.369230   6.996235  2505880.0
# 2  2017-07-26  7.323076  7.442307  7.276923  7.326923   6.956069  2112240.0
# 3  2017-07-27  7.388461  7.419230  7.223076  7.269230   6.901296  1910480.0
# 4  2017-07-28  7.261538  7.296153  7.165384  7.200000   6.835570  2866760.0

# %%
arquivo.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 988  2021-07-15  35.000000  35.590000  34.900002  34.919998  34.919998
# 989  2021-07-16  35.040001  35.259998  34.209999  34.290001  34.290001
# 990  2021-07-19  34.000000  34.369999  33.599998  34.180000  34.180000
# 991  2021-07-20  34.049999  34.830002  33.869999  34.549999  34.549999
# 992  2021-07-21  34.750000  34.970001  34.099998  34.450001  34.450001
#
#         Volume
# 988  4807000.0
# 989  5380000.0
# 990  4756600.0
# 991  4042300.0
# 992  4315700.0

# %% [markdown]
# ## 3.3. Manipulação de diretórios

# %% [markdown]
# Podemos fazer algumas modificações e ajustes um pouco mais avançados. E se o arquivo não estiver na pasta onde está o código que você está criando?
#
# Primeiro verifique qual o endereço que o Python está "vendo" naquele momento

# %%
import os

# %%
caminho = os.getcwd()

# %%
caminho
# Out:
# '/content'

# %%
arquivo = pd.read_csv('WEGE3.SA.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-5683cf767570> in <cell line: 1>()
# ----> 1 arquivo = pd.read_csv('WEGE3.SA.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
caminho + '/Arquivos'
# Out:
# '/content/Arquivos'

# %%
novo_caminho = caminho + '/Arquivos'

# %% [markdown]
# E se quiséssemos mudar o diretório? Basta usar o seguinte comando:

# %%
os.chdir(novo_caminho)

# %%
os.getcwd()
# Out:
# '/content/Arquivos'

# %%
arquivo = pd.read_csv('WEGE3.SA.csv')

# %%
arquivo.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2017-07-24  7.392307  7.473076  7.261538  7.426923   7.051007  2638220.0
# 1  2017-07-25  7.476923  7.476923  7.307692  7.369230   6.996235  2505880.0
# 2  2017-07-26  7.323076  7.442307  7.276923  7.326923   6.956069  2112240.0
# 3  2017-07-27  7.388461  7.419230  7.223076  7.269230   6.901296  1910480.0
# 4  2017-07-28  7.261538  7.296153  7.165384  7.200000   6.835570  2866760.0

# %% [markdown]
# # 4. Análises do mercado financeiro

# %% [markdown]
# ## 4.1. Obtenção de dados

# %% [markdown]
# Utilizando a biblioteca yfinance, vamos obter os dados de negociação para algum papel, como por exemplo PETR4

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

# %%
petro = yf.download('PETR4.SA', start = '2017-01-01', end = '2022-02-10')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
petro.Close.plot();

# %% [markdown]
# ## 4.2. Médias móveis

# %%
petro.head(30)
# Out:
#                  Open       High    Low      Close  Adj Close    Volume
# Date
# 2017-01-02  14.640000  14.700000  14.60  14.660000   5.749560   7525700
# 2017-01-03  14.950000  15.650000  14.95  15.500000   6.079003  39947800
# 2017-01-04  15.450000  15.680000  15.31  15.500000   6.079003  37071700
# 2017-01-05  15.700000  15.910000  15.62  15.750000   6.177052  47586300
# 2017-01-06  15.780000  15.920000  15.50  15.660000   6.141754  25592000
# 2017-01-09  15.500000  15.600000  15.33  15.330000   6.012330  25599000
# 2017-01-10  15.600000  15.680000  15.39  15.480000   6.071157  26239900
# 2017-01-11  15.640000  15.680000  15.27  15.660000   6.141754  34399300
# 2017-01-12  16.150000  16.250000  15.90  15.900000   6.235881  49890300
# 2017-01-13  15.770000  15.950000  15.57  15.680000   6.149597  34450000
# 2017-01-16  15.700000  15.750000  15.58  15.750000   6.177052  20069600
# 2017-01-17  15.730000  15.970000  15.72  15.820000   6.204505  28663300
# ...

# %% [markdown]
# Vamos criar uma média móvel do preço

# %%
petro.Close.head(10)
# Out:
# Date
# 2017-01-02    14.66
# 2017-01-03    15.50
# 2017-01-04    15.50
# 2017-01-05    15.75
# 2017-01-06    15.66
# 2017-01-09    15.33
# 2017-01-10    15.48
# 2017-01-11    15.66
# 2017-01-12    15.90
# 2017-01-13    15.68
# Name: Close, dtype: float64

# %%
petro.Close.head(10).mean()
# Out:
# 15.511999893188477

# %%
petro.Close.rolling(10).mean().head(15)
# Out:
# Date
# 2017-01-02       NaN
# 2017-01-03       NaN
# 2017-01-04       NaN
# 2017-01-05       NaN
# 2017-01-06       NaN
# 2017-01-09       NaN
# 2017-01-10       NaN
# 2017-01-11       NaN
# 2017-01-12       NaN
# 2017-01-13    15.512
# 2017-01-16    15.621
# 2017-01-17    15.653
# 2017-01-18    15.682
# 2017-01-19    15.684
# 2017-01-20    15.718
# Name: Close, dtype: float64

# %%
petro.Close.rolling(5).mean().plot();

# %%
petro.Close.rolling(10).mean().plot();

# %%
petro.Close.rolling(50).mean().plot();

# %% [markdown]
# ## 4.3. Retornos diários

# %%
petro.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2017-01-02  14.64  14.70  14.60  14.66   5.749560   7525700
# 2017-01-03  14.95  15.65  14.95  15.50   6.079003  39947800
# 2017-01-04  15.45  15.68  15.31  15.50   6.079003  37071700
# 2017-01-05  15.70  15.91  15.62  15.75   6.177052  47586300
# 2017-01-06  15.78  15.92  15.50  15.66   6.141754  25592000

# %% [markdown]
# Calcular os retornos diários com base na coluna Adj Close

# %%
retornos = petro['Adj Close'].pct_change()

# %%
petro['Adj Close'].pct_change().plot();

# %% [markdown]
# Retorno diário médio

# %%
retornos.mean()
# Out:
# 0.0012970050339934256

# %% [markdown]
# Média móvel dos retornos

# %%
retornos.rolling(50).mean().plot();

# %% [markdown]
# ## 4.4. Volatilidade

# %% [markdown]
# A medida mais básica de volatilidade que podemos ter é o desvio padrão

# %% [markdown]
# Calculando o desvio padrão dos retornos diários

# %%
retornos.std()
# Out:
# 0.02989426697431975

# %% [markdown]
# Portanto, essa é a volatilidade de PETR4 no período
#
# E se quiséssemos visualizar a volatilidade em janelas de tempo, isto é, o comportamento da volatilidade de PETR4 ao longo de períodos específicos de tempo, por exemplo, 10 dias?

# %%
janelas_vol = retornos.rolling(10).std()

# %%
janelas_vol.plot();

# %% [markdown]
# ## 4.5. Métricas estatísticas

# %%
retornos.describe()
# Out:
# count    1270.000000
# mean        0.001297
# std         0.029894
# min        -0.296978
# 25%        -0.012087
# 50%         0.001134
# 75%         0.014859
# max         0.222222
# Name: Adj Close, dtype: float64

# %% [markdown]
# ## 4.6. Distribuição dos retornos

# %% [markdown]
# Forma de entender onde os retornos se "concentram" com o tempo

# %%
retornos.plot.hist(bins = 100);

# %% [markdown]
# ## 4.7. Métricas de retorno acumulado

# %%
ret_acum = (retornos + 1).cumprod()

# %%
ret_acum.plot(figsize = (12,6));

# %% [markdown]
# Vamos calcular agora o cumulativo máximo, ou seja, os picos atingidos ao longo do tempo

# %%
picos = ret_acum.cummax()

# %%
picos.plot(figsize = (12,6));

# %%
retornos = pd.DataFrame(retornos)

# %%
retornos.head()
# Out:
#             Adj Close
# Date
# 2017-01-02        NaN
# 2017-01-03   0.057299
# 2017-01-04   0.000000
# 2017-01-05   0.016129
# 2017-01-06  -0.005714

# %%
retornos['Retorno Acumulado'] = ret_acum
retornos['Picos'] = picos

# %%
retornos.head()
# Out:
#             Adj Close  Retorno Acumulado     Picos
# Date
# 2017-01-02        NaN                NaN       NaN
# 2017-01-03   0.057299           1.057299  1.057299
# 2017-01-04   0.000000           1.057299  1.057299
# 2017-01-05   0.016129           1.074352  1.074352
# 2017-01-06  -0.005714           1.068213  1.074352

# %%
retornos[['Retorno Acumulado', 'Picos']].plot(figsize = (12,6));

# %% [markdown]
# ### Drawdown

# %%
drawdown = (ret_acum - picos)/picos

# %%
drawdown.plot(figsize = (12,6));

# %% [markdown]
# Qual o drawdown máximo? É justamente o valor mais 'fundo' que o gráfico acima atinge

# %%
drawdown.min()
# Out:
# -0.6335605693103294

# %% [markdown]
# ## 4.8. Normalização

# %%
acoes = ['PETR4.SA', 'WEGE3.SA', 'MGLU3.SA', 'LREN3.SA', 'VALE3.SA', 'BPAC11.SA','OIBR3.SA']

# %%
dados = yf.download(acoes, start="2019-01-01", end="2022-05-15")['Adj Close']
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
dados.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
dados.head()
# Out:
#             BPAC11.SA   LREN3.SA  MGLU3.SA  OIBR3.SA   PETR4.SA   VALE3.SA  \
# Date
# 2019-01-02   5.608783  35.906548  5.641578      12.6   9.843831  36.257854
# 2019-01-03   5.840792  35.453079  5.581216      14.1  10.085219  34.774616
# 2019-01-04   6.048025  34.092659  5.411353      14.1  10.113860  37.038509
# 2019-01-07   6.171914  33.309410  5.495374      14.2  10.273425  36.839798
# 2019-01-08   6.056981  34.381233  5.451089      13.8  10.212053  37.194641
#
#             WEGE3.SA
# Date
# 2019-01-02  8.468706
# 2019-01-03  8.661821
# 2019-01-04  8.760731
# 2019-01-07  8.624143
# 2019-01-08  8.553488

# %% [markdown]
# Normalização na base 1

# %%
normalizado = dados/dados.iloc[0]

# %%
normalizado.head()
# Out:
#             BPAC11.SA  LREN3.SA  MGLU3.SA  OIBR3.SA  PETR4.SA  VALE3.SA  \
# Date
# 2019-01-02   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2019-01-03   1.041365  0.987371  0.989300  1.119048  1.024522  0.959092
# 2019-01-04   1.078313  0.949483  0.959191  1.119048  1.027431  1.021531
# 2019-01-07   1.100402  0.927670  0.974085  1.126984  1.043641  1.016050
# 2019-01-08   1.079910  0.957520  0.966235  1.095238  1.037406  1.025837
#
#             WEGE3.SA
# Date
# 2019-01-02  1.000000
# 2019-01-03  1.022803
# 2019-01-04  1.034483
# 2019-01-07  1.018354
# 2019-01-08  1.010011

# %%
normalizado.tail()
# Out:
#             BPAC11.SA  LREN3.SA  MGLU3.SA  OIBR3.SA  PETR4.SA  VALE3.SA  \
# Date
# 2022-05-09   3.929891  0.643814  0.693068  0.547619  1.859003  1.955901
# 2022-05-10   4.047667  0.666721  0.700159  0.571429  1.875188  1.931609
# 2022-05-11   3.919499  0.661062  0.696614  0.555556  1.940508  2.012157
# 2022-05-12   4.097894  0.681274  0.740927  0.555556  1.955537  1.991956
# 2022-05-13   4.200082  0.686394  0.776379  0.547619  1.980971  1.989654
#
#             WEGE3.SA
# Date
# 2022-05-09  3.095869
# 2022-05-10  3.033162
# 2022-05-11  3.030840
# 2022-05-12  3.066838
# 2022-05-13  3.077289

# %%
normalizado.plot();

# %% [markdown]
# # 5. Plot de cotação com volume

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Vamos extrair dados para um ativo só

# %%
jbs = yf.download('JBSS3.SA', start = '2021-01-01', end = '2023-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
jbs.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2021-01-04  23.900000  24.170000  23.290001  23.410000  19.446707  10914500
# 2021-01-05  23.290001  23.750000  22.799999  23.750000  19.729143  17855900
# 2021-01-06  23.750000  24.090000  23.450001  23.540001  19.554699  14518700
# 2021-01-07  23.610001  24.379999  23.600000  23.830000  19.795601  16820400
# 2021-01-08  23.910000  24.610001  23.889999  24.400000  20.269100  19156200

# %%
jbs.Close.plot();

# %%
jbs.Volume.plot();

# %%
fig = plt.figure(figsize = (10,5))
gs = fig.add_gridspec(nrows = 6, ncols = 1)

ax1 = fig.add_subplot(gs[0:5, 0])
ax2 = fig.add_subplot(gs[5, 0])

ax1.plot(jbs.Close)
ax2.bar(jbs.index, jbs.Volume)

ax1.set_title('Fechamento | Volume | Cotação ed JBSS3')
# Out:
# Text(0.5, 1.0, 'Fechamento | Volume | Cotação ed JBSS3')

# %% [markdown]
# # 6. Estudo de caso: matriz de correlação

# %%
import yfinance as yf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from functools import reduce

# %% [markdown]
# ## 6.1. Importando dados de FIIs, ETFs e BDRs

# %%
ativos = ['KNRI11.SA', 'ONEF11.SA', 'HCTR11.SA', 'HGLG11.SA',
          'HGBS11.SA', 'SMAL11.SA', 'IVVB11.SA', 'AAPL34.SA']

# %%
ativos = yf.download(ativos, start = '2017-01-01')['Adj Close']
# Out:
# [*********************100%***********************]  8 of 8 completed

# %% [markdown]
# ## 6.2. Importando dados de moedas, índices, e criptomoedas

# %%
cesta = ['USDBRL=X', 'EURBRL=X', '^BVSP','^GSPC', 'BTC-USD', 'ETH-USD']

# %%
cesta = yf.download(cesta, start = '2017-01-01')['Adj Close']
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
cesta.head()
# Out:
#                 BTC-USD  ETH-USD  EURBRL=X  USDBRL=X    ^BVSP        ^GSPC
# Date
# 2017-01-01   998.325012      NaN       NaN       NaN      NaN          NaN
# 2017-01-02  1021.750000      NaN    3.4190    3.2532  59589.0          NaN
# 2017-01-03  1043.839966      NaN    3.4320    3.2840  61814.0  2257.830078
# 2017-01-04  1154.729980      NaN    3.3976    3.2635  61589.0  2270.750000
# 2017-01-05  1013.380005      NaN    3.3732    3.2141  62071.0  2269.000000

# %%
cesta.rename(columns = {'USDBRL=X': 'Dolar',
                        'EURUSD=X': 'Euro',
                        '^BVSP': 'Ibov',
                        '^GSPC': 'S&P500',
                        'BTC-USD': 'Bitcoin',
                        'ETH-USD': 'Ethereum'}, inplace = True)

# %% [markdown]
# ## 6.3. Importando dados de ações

# %%
acoes = ['PETR4.SA', 'WEGE3.SA', 'MGLU3.SA', 'LREN3.SA', 'VALE3.SA', 'BPAC11.SA','OIBR3.SA']

# %%
acoes = yf.download(acoes, start = '2017-01-01')['Adj Close']
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
acoes.head()
# Out:
#             BPAC11.SA   LREN3.SA  MGLU3.SA   OIBR3.SA  PETR4.SA   VALE3.SA  \
# Date
# 2017-01-02        NaN  16.919130  0.379203  19.702110  5.749559  16.365671
# 2017-01-03        NaN  17.438259  0.378047  19.776739  6.079002  17.090569
# 2017-01-04        NaN  17.284716  0.357915  19.552851  6.079002  16.783630
# 2017-01-05        NaN  17.123856  0.370218  19.925997  6.177051  17.423630
# 2017-01-06        NaN  16.926435  0.367832  20.000626  6.141753  16.959955
#
#             WEGE3.SA
# Date
# 2017-01-02  5.274140
# 2017-01-03  5.539595
# 2017-01-04  5.406867
# 2017-01-05  5.392893
# 2017-01-06  5.438301

# %% [markdown]
# ## 6.4. Juntando tudo num dataframe só

# %%
dfs = [ativos, cesta, acoes]

# %%
df_final = reduce(lambda left, right: pd.merge(left, right, how = 'inner', on = 'Date'),dfs)

# %%
df_final.head()
# Out:
#             AAPL34.SA  HCTR11.SA   HGBS11.SA  HGLG11.SA  IVVB11.SA  \
# Date
# 2017-01-02   4.412901        NaN  183.157333  97.012894  78.639999
# 2017-01-03   4.366205        NaN  182.614349  97.012894  76.250000
# 2017-01-04   4.351028        NaN  182.342880  97.012894  75.940002
# 2017-01-05   4.375544        NaN  182.071396  97.012894  75.260002
# 2017-01-06   4.400060        NaN  182.795349  97.012894  76.300003
#
#              KNRI11.SA  ONEF11.SA  SMAL11.SA      Bitcoin  Ethereum  ...  \
# Date                                                                 ...
# 2017-01-02  127.742592  85.993904  54.000000  1021.750000       NaN  ...
# 2017-01-03  127.661224  86.178833  55.450001  1043.839966       NaN  ...
# 2017-01-04  129.216095  86.178833  56.990002  1154.729980       NaN  ...
# 2017-01-05  129.270340  85.069221  56.990002  1013.380005       NaN  ...
# 2017-01-06  130.129120  85.069221  56.500000   902.200989       NaN  ...
#
# ...

# %% [markdown]
# ## 6.5. Preparar os dados para a criação da matriz de correlação

# %%
retornos = df_final.pct_change()

# %%
retornos = retornos.dropna()

# %%
retornos.head()
# Out:
#             AAPL34.SA  HCTR11.SA  HGBS11.SA  HGLG11.SA  IVVB11.SA  KNRI11.SA  \
# Date
# 2019-07-12   0.000661   0.007194  -0.004078   0.004096   0.001920   0.005945
# 2019-07-15   0.013335  -0.008589  -0.004679   0.006447   0.005831   0.001313
# 2019-07-16   0.000651   0.001819  -0.002390   0.022225  -0.002981   0.000000
# 2019-07-17  -0.005599   0.000000   0.001021  -0.003070  -0.005316  -0.000328
# 2019-07-18  -0.001702   0.000000   0.002393  -0.000577  -0.006180   0.000328
#
#             ONEF11.SA  SMAL11.SA   Bitcoin  Ethereum  ...     Dolar      Ibov  \
# Date                                                  ...
# 2019-07-12   0.000337  -0.013081  0.040262  0.028182  ...  0.001200 -0.011793
# 2019-07-15  -0.001616  -0.006216 -0.077936 -0.168312  ... -0.005433 -0.000991
# 2019-07-16  -0.008363   0.000276 -0.130100 -0.133118  ...  0.005168 -0.000270
# 2019-07-17   0.006666   0.007356  0.022807  0.061732  ...  0.003596  0.000781
# ...

# %% [markdown]
# ## 6.6. Matriz de correlação

# %%
correlacao = retornos.corr()

# %%
correlacao
# Out:
#            AAPL34.SA  HCTR11.SA  HGBS11.SA  HGLG11.SA  IVVB11.SA  KNRI11.SA  \
# AAPL34.SA       1.00       0.05       0.08       0.08       0.76       0.07
# HCTR11.SA       0.05       1.00       0.19       0.12       0.07       0.14
# HGBS11.SA       0.08       0.19       1.00       0.54       0.13       0.45
# HGLG11.SA       0.08       0.12       0.54       1.00       0.15       0.50
# IVVB11.SA       0.76       0.07       0.13       0.15       1.00       0.11
# KNRI11.SA       0.07       0.14       0.45       0.50       0.11       1.00
# ONEF11.SA       0.02       0.06       0.34       0.33       0.04       0.29
# SMAL11.SA       0.15       0.17       0.38       0.37       0.20       0.34
# Bitcoin         0.21       0.01       0.12       0.12       0.25       0.12
# Ethereum        0.22       0.03       0.12       0.09       0.26       0.10
# EURBRL=X        0.02      -0.02      -0.07      -0.01       0.04       0.01
# ...

# %%
sns.heatmap(correlacao)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (16,8))

sns.heatmap(correlacao,
            vmin = -1, vmax = 1, annot = True, cmap = 'BrBG'
)
# Out:
# <Axes: >

# %% [markdown]
# # 7. Estudo de caso: comparação de carteira com o IBOV

# %% [markdown]
# Simplificação: vamos simular um único aporte feito no primeiro dia

# %%
import pandas as pd
import yfinance as yf

# %% [markdown]
# ## 7.1. Importação dos dados

# %%
ativos = ['PETR4','VALE3', 'ABEV3', 'WEGE3', 'EMBR3', 'RADL3', 'CVCB3', 'CIEL3', 'OIBR3', 'KNRI11']

# %%
ativos = [i + '.SA' for i in ativos]

# %%
df = yf.download(ativos, start = '2021-01-01')['Adj Close']
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
df.head()
# Out:
#              ABEV3.SA  CIEL3.SA   CVCB3.SA  EMBR3.SA   KNRI11.SA   OIBR3.SA  \
# Date
# 2021-01-04  14.085718  3.240515  20.170000      8.37  146.840576  23.500000
# 2021-01-05  14.385996  3.165734  20.230000      8.57  146.045456  24.799999
# 2021-01-06  14.677172  3.090953  20.379999      8.90  146.100281  24.400000
# 2021-01-07  14.604378  3.115880  19.559999      8.88  146.182541  24.600000
# 2021-01-08  15.041146  3.182352  19.510000      8.81  145.817001  24.299999
#
#              PETR4.SA   RADL3.SA   VALE3.SA   WEGE3.SA
# Date
# 2021-01-04  12.221936  23.486469  69.413048  35.984741
# 2021-01-05  12.699654  23.420786  70.581833  38.193405
# 2021-01-06  12.725018  22.876554  72.896599  39.206116
# 2021-01-07  13.105502  22.585672  77.655182  40.826439
# 2021-01-08  13.156231  23.242504  77.412315  43.295506

# %% [markdown]
# ## 7.2. Métricas básicas de carteira

# %% [markdown]
# Preços do dia do aporte

# %%
primeiro = df.iloc[0]

# %% [markdown]
# Se investimos R$ 1000 em cada papel, quantos papéis precisamos comprar de cada?

# %%
num_papeis = 1000/primeiro

# %% [markdown]
# Número de papéis arredondados

# %%
comprados = round(num_papeis, 0)

# %% [markdown]
# ## 7.3. Construção da carteira

# %% [markdown]
# Como saber qual era o valor que tínhamos em cada papel, por dia? Basta multiplicar o número de papéis que compramos com os preços diários

# %%
PL = df*comprados

# %%
PL.head()
# Out:
#                ABEV3.SA     CIEL3.SA     CVCB3.SA     EMBR3.SA    KNRI11.SA  \
# Date
# 2021-01-04  1000.085989  1001.319207  1008.500004   996.029986  1027.884033
# 2021-01-05  1021.405706   978.211822  1011.499977  1019.829964  1022.318192
# 2021-01-06  1042.079191   955.104438  1018.999958  1059.099955  1022.701965
# 2021-01-07  1036.910820   962.806998   977.999973  1056.720014  1023.277786
# 2021-01-08  1067.921386   983.346788   975.500011  1048.390050  1020.719009
#
#                OIBR3.SA     PETR4.SA     RADL3.SA     VALE3.SA     WEGE3.SA
# Date
# 2021-01-04  1010.500000  1002.198771  1009.918179   971.782669  1007.572754
# 2021-01-05  1066.399967  1041.371597  1007.093794   988.145660  1069.415344
# 2021-01-06  1049.199984  1043.451439   983.691843  1020.552383  1097.771240
# 2021-01-07  1057.800016  1074.651175   971.183912  1087.172546  1143.140289
# 2021-01-08  1044.899967  1078.810936   999.427677  1083.772415  1212.274155

# %%
PL.tail()
# Out:
#                ABEV3.SA     CIEL3.SA    CVCB3.SA     EMBR3.SA    KNRI11.SA  \
# Date
# 2023-05-17  1033.760030  1705.679994  150.000000  2153.900045  1078.979996
# 2023-05-18  1033.050014  1708.770065  154.499996  2151.519991  1074.850021
# 2023-05-19  1035.179995  1665.509959  152.499998  2144.380054  1071.700043
# 2023-05-22  1038.019992  1603.710018  160.000002  2145.570082  1060.500000
# 2023-05-23  1035.890011  1606.799941  151.999998  2113.440027  1052.450043
#
#              OIBR3.SA     PETR4.SA     RADL3.SA    VALE3.SA     WEGE3.SA
# Date
# 2023-05-17  46.440002  2104.119987  1161.000000  978.319962  1104.879974
# 2023-05-18  46.440002  2116.419956  1178.365410  979.720047  1100.399979
# 2023-05-19  46.010002  2113.140038  1184.567295  968.939987  1123.640030
# 2023-05-22  47.730001  2100.840069  1200.560003  953.399979  1130.080017
# 2023-05-23  46.010002  2152.500000  1207.870007  931.839966  1126.160034

# %% [markdown]
# Criando uma nova coluna que vai demonstrar o valor total da nossa carteira, por dia

# %%
PL['PL Total'] = PL.sum(axis = 1)

# %%
PL.head()
# Out:
#                ABEV3.SA     CIEL3.SA     CVCB3.SA     EMBR3.SA    KNRI11.SA  \
# Date
# 2021-01-04  1000.085989  1001.319207  1008.500004   996.029986  1027.884033
# 2021-01-05  1021.405706   978.211822  1011.499977  1019.829964  1022.318192
# 2021-01-06  1042.079191   955.104438  1018.999958  1059.099955  1022.701965
# 2021-01-07  1036.910820   962.806998   977.999973  1056.720014  1023.277786
# 2021-01-08  1067.921386   983.346788   975.500011  1048.390050  1020.719009
#
#                OIBR3.SA     PETR4.SA     RADL3.SA     VALE3.SA     WEGE3.SA  \
# Date
# 2021-01-04  1010.500000  1002.198771  1009.918179   971.782669  1007.572754
# 2021-01-05  1066.399967  1041.371597  1007.093794   988.145660  1069.415344
# 2021-01-06  1049.199984  1043.451439   983.691843  1020.552383  1097.771240
# 2021-01-07  1057.800016  1074.651175   971.183912  1087.172546  1143.140289
# 2021-01-08  1044.899967  1078.810936   999.427677  1083.772415  1212.274155
#
#                 PL Total
# Date
# ...

# %%
PL.tail()
# Out:
#                ABEV3.SA     CIEL3.SA    CVCB3.SA     EMBR3.SA    KNRI11.SA  \
# Date
# 2023-05-17  1033.760030  1705.679994  150.000000  2153.900045  1078.979996
# 2023-05-18  1033.050014  1708.770065  154.499996  2151.519991  1074.850021
# 2023-05-19  1035.179995  1665.509959  152.499998  2144.380054  1071.700043
# 2023-05-22  1038.019992  1603.710018  160.000002  2145.570082  1060.500000
# 2023-05-23  1035.890011  1606.799941  151.999998  2113.440027  1052.450043
#
#              OIBR3.SA     PETR4.SA     RADL3.SA    VALE3.SA     WEGE3.SA  \
# Date
# 2023-05-17  46.440002  2104.119987  1161.000000  978.319962  1104.879974
# 2023-05-18  46.440002  2116.419956  1178.365410  979.720047  1100.399979
# 2023-05-19  46.010002  2113.140038  1184.567295  968.939987  1123.640030
# 2023-05-22  47.730001  2100.840069  1200.560003  953.399979  1130.080017
# 2023-05-23  46.010002  2152.500000  1207.870007  931.839966  1126.160034
#
#                 PL Total
# Date
# 2023-05-17  11517.079990
# ...

# %%
PL['PL Total'].plot();

# %% [markdown]
# ## 7.4. Comparação com o IBOV

# %% [markdown]
# Vamos obter agora os dados do IBOV para compará-lo com nossa carteira

# %%
ibov = yf.download('^BVSP', start = '2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov.rename(columns = {'Close':'IBOV'}, inplace = True)

# %%
ibov = ibov[['IBOV']]

# %%
ibov
# Out:
#                     IBOV
# Date
# 2021-01-04  118558.00000
# 2021-01-05  119223.00000
# 2021-01-06  119851.00000
# 2021-01-07  121956.00000
# 2021-01-08  125077.00000
# ...                  ...
# 2023-05-17  109460.00000
# 2023-05-18  110108.00000
# 2023-05-19  110745.00000
# 2023-05-22  110213.00000
# 2023-05-23  109928.53125
#
# [594 rows x 1 columns]

# %% [markdown]
# Agora vamos juntar os dados das tabelas do IBOV e da nossa carteira

# %%
novo_df = pd.merge(ibov, PL, how = 'inner', on = 'Date')

# %%
novo_df.head()
# Out:
#                 IBOV     ABEV3.SA     CIEL3.SA     CVCB3.SA     EMBR3.SA  \
# Date
# 2021-01-04  118558.0  1000.085989  1001.319207  1008.500004   996.029986
# 2021-01-05  119223.0  1021.405706   978.211822  1011.499977  1019.829964
# 2021-01-06  119851.0  1042.079191   955.104438  1018.999958  1059.099955
# 2021-01-07  121956.0  1036.910820   962.806998   977.999973  1056.720014
# 2021-01-08  125077.0  1067.921386   983.346788   975.500011  1048.390050
#
#               KNRI11.SA     OIBR3.SA     PETR4.SA     RADL3.SA     VALE3.SA  \
# Date
# 2021-01-04  1027.884033  1010.500000  1002.198771  1009.918179   971.782669
# 2021-01-05  1022.318192  1066.399967  1041.371597  1007.093794   988.145660
# 2021-01-06  1022.701965  1049.199984  1043.451439   983.691843  1020.552383
# 2021-01-07  1023.277786  1057.800016  1074.651175   971.183912  1087.172546
# 2021-01-08  1020.719009  1044.899967  1078.810936   999.427677  1083.772415
#
#                WEGE3.SA      PL Total
# Date
# ...

# %%
novo_df.tail()
# Out:
#                     IBOV     ABEV3.SA     CIEL3.SA    CVCB3.SA     EMBR3.SA  \
# Date
# 2023-05-17  109460.00000  1033.760030  1705.679994  150.000000  2153.900045
# 2023-05-18  110108.00000  1033.050014  1708.770065  154.499996  2151.519991
# 2023-05-19  110745.00000  1035.179995  1665.509959  152.499998  2144.380054
# 2023-05-22  110213.00000  1038.019992  1603.710018  160.000002  2145.570082
# 2023-05-23  109928.53125  1035.890011  1606.799941  151.999998  2113.440027
#
#               KNRI11.SA   OIBR3.SA     PETR4.SA     RADL3.SA    VALE3.SA  \
# Date
# 2023-05-17  1078.979996  46.440002  2104.119987  1161.000000  978.319962
# 2023-05-18  1074.850021  46.440002  2116.419956  1178.365410  979.720047
# 2023-05-19  1071.700043  46.010002  2113.140038  1184.567295  968.939987
# 2023-05-22  1060.500000  47.730001  2100.840069  1200.560003  953.399979
# 2023-05-23  1052.450043  46.010002  2152.500000  1207.870007  931.839966
#
#                WEGE3.SA      PL Total
# Date
# ...

# %%
novo_df.plot();

# %% [markdown]
# Vamos normalizar tudo para colocá-los na mesma base, ou seja, todos começam com 100

# %%
novo_normalizado = (novo_df/novo_df.iloc[0])*100

# %%
novo_normalizado.plot();

# %%
novo_normalizado[['IBOV', 'PL Total']].plot(figsize = (14,7));
